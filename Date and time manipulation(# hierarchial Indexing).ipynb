# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # hierarchial Indexing

# %%
raw_dat={'company':['goo','goo','goo','goo','fb','fb','fb','fb','amz','amz','amz','amz'],
          'project':['1st','1st','2nd','2nd','1st','1st','2nd','2nd','1st','1st','2nd','2nd'],
          'incharge':['s','r','re','se','ma','she','ed','da','jef','and','keith','edw'],
          'sales':[43,43,54,67,78,89,54,65,78,88,98,23],
          'profit':[13,23,45,35,67,78,89,45,67,46,34,45]}

# %%
df12=pd.DataFrame(raw_dat)
df12
# Out:
#    company project incharge  sales  profit
# 0      goo     1st        s     43      13
# 1      goo     1st        r     43      23
# 2      goo     2nd       re     54      45
# 3      goo     2nd       se     67      35
# 4       fb     1st       ma     78      67
# 5       fb     1st      she     89      78
# 6       fb     2nd       ed     54      89
# 7       fb     2nd       da     65      45
# 8      amz     1st      jef     78      67
# 9      amz     1st      and     88      46
# 10     amz     2nd    keith     98      34
# 11     amz     2nd      edw     23      45

# %%
#to categorise the index on the basis of category

df12.set_index(['company','project','incharge'])
# Out:
#                           sales  profit
# company project incharge
# goo     1st     s            43      13
#                 r            43      23
#         2nd     re           54      45
#                 se           67      35
# fb      1st     ma           78      67
#                 she          89      78
#         2nd     ed           54      89
#                 da           65      45
# amz     1st     jef          78      67
#                 and          88      46
#         2nd     keith        98      34
#                 edw          23      45

# %%
#to categorise the index on the basis of category


df12.set_index(['company','project','incharge'])
# Out:
#                           sales  profit
# company project incharge
# goo     1st     s            43      13
#                 r            43      23
#         2nd     re           54      45
#                 se           67      35
# fb      1st     ma           78      67
#                 she          89      78
#         2nd     ed           54      89
#                 da           65      45
# amz     1st     jef          78      67
#                 and          88      46
#         2nd     keith        98      34
#                 edw          23      45

# %%
#check this code 

df12.swaplevel('company','project')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 #check this code
# ----> 3 df12.swaplevel('company','project')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\frame.py:6860, in DataFrame.swaplevel(self, i, j, axis)
#    6857 axis = self._get_axis_number(axis)
#    6859 if not isinstance(result._get_axis(axis), MultiIndex):  # pragma: no cover
# -> 6860     raise TypeError("Can only swap levels on a hierarchical axis.")
#    6862 if axis == 0:
#    6863     assert isinstance(result.index, MultiIndex)
#
# TypeError: Can only swap levels on a hierarchical axis.

# %%
df12.sum(level='company')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 df12.sum(level='company')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:11067, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11047 @doc(
#   11048     _num_doc,
#   11049     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11065     **kwargs,
#   11066 ):
# > 11067     return NDFrame.sum(
#   11068         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11069     )
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:10787, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10778 def sum(
#   10779     self,
#   10780     axis: Axis | None = None,
#    (...)
#   10785     **kwargs,
#   10786 ):
# ...
